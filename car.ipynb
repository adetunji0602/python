# %%
import matplotlib.pyplot as plt
import pandas as pd
Year = [2020,2020,2020,2010,2020,2012,2012,2008,2008,2019,2019,2019,2019,2018,2000,2000,2004,2004,2019,2019]
Brand = ["Acura","Acura","Acura","Alfa Romeo","Alfa Romeo","Audi","Audi","BMW","BMW","Buick","Buick","Buick","Buick","Cadillac","Audi","Audi","BMW","BMW","Chevrolet","Chevrolet"]
plt.plot(Brand, Year)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(Year,Brand)
plt.xlabel('Model')
plt.ylabel('Brand')
# Out:
# Text(0, 0.5, 'Brand')
